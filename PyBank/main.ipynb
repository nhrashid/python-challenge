# %%
# Import Dependencies
import pandas as pd
import os

# %%
# Create a path to the csv and read it into a Pandas DataFrame
csv_path = "Resources/budget_data.csv"
data_df = pd.read_csv(csv_path)

data_df
# Out:
#         Date  Profit/Losses
# 0   Jan-2010         867884
# 1   Feb-2010         984655
# 2   Mar-2010         322013
# 3   Apr-2010         -69417
# 4   May-2010         310503
# 5   Jun-2010         522857
# 6   Jul-2010        1033096
# 7   Aug-2010         604885
# 8   Sep-2010        -216386
# 9   Oct-2010         477532
# 10  Nov-2010         893810
# 11  Dec-2010         -80353
# 12  Jan-2011         779806
# 13  Feb-2011        -335203
# 14  Mar-2011         697845
# 15  Apr-2011         793163
# 16  May-2011         485070
# 17  Jun-2011         584122
# 18  Jul-2011          62729
# 19  Aug-2011         668179
# 20  Sep-2011         899906
# 21  Oct-2011         834719
# 22  Nov-2011         132003
# 23  Dec-2011         309978
# 24  Jan-2012        -755566
# 25  Feb-2012        1170593
# 26  Mar-2012         252788
# 27  Apr-2012        1151518
# 28  May-2012         817256
# 29  Jun-2012         570757
# ..       ...            ...
# 56  Sep-2014        1166643
# ...

# %%
# Print to terminal
str2 = "Financial Analysis"
print(str2)  
str3 = "----------------------------"
print(str3)
str4 = "Total Months:" + data_df["Date"].count().astype(str)
print(str4)
str5 = "Total: " + data_df["Profit/Losses"].astype(float).sum().astype(str)
print(str5)
max = data_df["Profit/Losses"].astype(float).max()
df = data_df["Profit/Losses"] == max

str6= "Greatest Increase in Profits:" + data_df[df]['Date'].iloc[0]+" " +data_df["Profit/Losses"].astype(float).max().astype(str)
print(str6)

min = data_df["Profit/Losses"].astype(float).min()
df = data_df["Profit/Losses"] == min

str7 = "Greatest Decrease in Profits:"   + data_df[df]['Date'].iloc[0]+" " + data_df["Profit/Losses"].astype(float).min().astype(str)
print(str7)
# Out:
# Financial Analysis
# ----------------------------
# Total Months:86
# Total: 38382578.0
# Greatest Increase in Profits:Feb-2012 1170593.0
# Greatest Decrease in Profits:Sep-2013 -1196225.0

# %%
# Export Result To Text File
str1 = str2+"\n"+str3+"\n"+str4+"\n"+str5+"\n"+str6+"\n" + str7+"\n"
print(str1)
#data_df.to_csv("Resources/fileOne.csv", index=False, header=True)
# Out:
# Financial Analysis
# ----------------------------
# Total Months:86
# Total: 38382578.0
# Greatest Increase in Profits:Feb-2012 1170593.0
# Greatest Decrease in Profits:Sep-2013 -1196225.0

# %%
# Export to Text File
base_filename = 'Values.txt'
with open(base_filename,'w') as outfile:
    outfile.write(str1)
